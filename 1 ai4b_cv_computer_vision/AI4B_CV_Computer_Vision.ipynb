# %% [markdown]
# ![alt text](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTK4gQ9nhwHHaSXMHpeggWg7twwMCgb877smkRmtkmDeDoGF9Z6&usqp=CAU)

# %% [markdown]
# #<font color = blue> Computer Vision

# %% [markdown]
# # Car Parking - Detecção de Vagas
#
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS3r7F30qSbqO3uQpGKm2EDmKA4-hnx2tdOPQ&s)

# %% [markdown]
#  ## <font color = blue> **1. Introdução ao Projeto**
#
#  ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ7tp8wXvd4udl_V_azLMjmHCQhqwAvK6FfZA&s)
#
# **Objetivo do Projeto:** O projeto visa detectar vagas de estacionamento livres em um estacionamento usando visão computacional.
#
# ###**Visão Geral:**
#
#
# As etapas principais:
#
#
# 1- seleção de posições de vagas,
#
# 2- processamento de vídeo, e
#
# 3- detecção de vagas ocupadas ou livres.

# %% [markdown]
# ##<font color = blue> 2. Configuração Inicial e Dependências
# **Instalação de Bibliotecas:**
#
# ![](data:image/jpeg;base64,...)
#
# A instalação das bibliotecas necessárias, como opencv-python, cvzone, e numpy.
#
# .
# .
#
#
# **Arquivos do Projeto:** Arquivos principais:
#
# 1- ParkingSpacePicker.py e
#
# 2- main.py

# %% [markdown]
# ##<font color = blue> 3. Seleção de Posições de Vagas (ParkingSpacePicker.py)
# ![](https://pyimagesearch.com/wp-content/uploads/2018/05/opencv_tutorial_header.jpg)
# .
#
# **Carregamento da Imagem**: Como carregar a imagem do estacionamento usando OpenCV.
#
# .
# .
#
# **Interação com o Mouse:** Como o script permite ao usuário clicar para selecionar as áreas das vagas de estacionamento na imagem.
#
# .
# .
#
# **Eventos do Mouse:** Eventos como cv2.EVENT_LBUTTONDOWN (adicionar posição) e cv2.EVENT_RBUTTONDOWN (remover posição).
#
# .
# .
#
# **Salvamento das Posições**: As posições das vagas são salvas em um arquivo usando pickle.
#
# .
# .
#
# **Exibição das Vagas:** Como as vagas selecionadas são desenhadas na imagem com retângulos.

# %% [markdown]
# ##<font color = blue> **4. Processamento de Vídeo e Detecção de Vagas** (main.py). </font>
#
# ![](data:image/jpeg;base64,...)
#
#
# 1. **Carregamento do Vídeo:** Mostre como o vídeo é carregado para ser processado quadro a quadro.
# Carregamento das Posições de Vagas: Explique como as posições salvas são carregadas usando pickle.
#
#
# 2. **Processamento de Imagem:**
#
#  = > **Conversão para Escala de Cinza:** Introduza a função cv2.cvtColor e o conceito de imagens em escala de cinza.
# Desfoque: Explique o uso do desfoque gaussiano para suavizar a imagem.
#
#  = > **Thresholding:** Explique o conceito de thresholding adaptativo e como ele transforma a imagem em preto e branco para facilitar a detecção de vagas.
#
#  = > **Dilatação:** Ensine sobre a dilatação da imagem para melhorar a detecção das bordas das vagas.
#
#
# 3. **Detecção de Vagas:**
#
#  = >  **Corte de Imagem:** Mostre como cortar a imagem em regiões de interesse (vagas) e contar os pixels brancos para detectar se a vaga está ocupada ou não.
#
#  = > **Contagem de Vagas Livres:** Explique como o script conta e exibe o número de vagas livres.

# %% [markdown]
# ## <font color = blue> **5. Execução do Projeto**
#
# ![](data:image/jpeg;base64,...
# )
#
# **Rodando os Scripts:** Mostre como rodar os scripts na ordem correta, primeiro o ParkingSpacePicker.py para selecionar as vagas, depois o main.py para a detecção no vídeo.
#
# **Interpretação dos Resultados:** Ensine como interpretar os resultados mostrados na tela, como o número de vagas livres.

# %% [markdown]
# ##<font color = blue> 6. **Exploração Avançada** (Opcional)
# ![](https://cdn.prod.website-files.com/646dd1f1a3703e451ba81ecc/64eb16a8c49943384133d847_ultralytics-car.webp)
#
# **Aprimoramento do Projeto:** Sugira algumas melhorias, como usar técnicas mais avançadas de processamento de imagem ou integração com outras ferramentas de IA.

# %% [markdown]
# #Fim
